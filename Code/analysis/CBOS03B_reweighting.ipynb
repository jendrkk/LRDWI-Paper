# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import sys

# Change root directory to the repo root (Jupyter: __file__ is not defined)
def find_repo_root(start=Path.cwd()):
	for p in [start] + list(start.parents):
		if (p / 'Code').exists() or (p / '.git').exists() or (p / 'local_repo').exists():
			return p
	return start

repo_root = find_repo_root()
data_root = repo_root.parent.parent / 'Data' / 'CBOS ready'

os.chdir(repo_root)
sys.path.append(str(repo_root / 'Code' / 'tools'))

JSON_ROOT = "/Users/jedrek/Documents/Studium Volkswirschaftslehre/3. Semester/Long-run dynamics of wealth inequalities/Paper/Data/CT json"

# %%
df = pd.read_csv(data_root / 'CBOS_data_to_weight.csv')
print(f"Loaded: {df.shape[0]:,} obs × {df.shape[1]} cols, {df['survey_file'].nunique()} surveys")
# Out:
# /var/folders/y8/4_9g68pj7k136q2yypgp5ysc0000gn/T/ipykernel_48289/2187004201.py:1: DtypeWarning: Columns (15,16,21,27,28,29,33,34,35,40,41,45,46,47,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_root / 'CBOS_data_to_weight.csv')
# Loaded: 355,352 obs × 87 cols, 327 surveys

# %%
df[df['teryt_id_VOIV_500'].apply(lambda x: x == '[]' if x is not None else True)][['survey_file', 'location_new_L', 'location_old_L', 'cs', 'cs_L', 'teryt_id_VOIV', 'teryt_id_VOIV_500', 'teryt_id_VOIV_100_500', 'teryt_id_VOIV_100']]
# Out:
#                  survey_file location_new_L    location_old_L   cs  \
# 2         CBOS_1_01_1990.sav            NaN         bydgoskie  5.0
# 3         CBOS_1_01_1990.sav            NaN         bydgoskie  5.0
# 4         CBOS_1_01_1990.sav            NaN      białostockie  5.0
# 5         CBOS_1_01_1990.sav            NaN  bialskopodlaskie  5.0
# 6         CBOS_1_01_1990.sav            NaN  bialskopodlaskie  5.0
# ...                      ...            ...               ...  ...
# 351422  CBOS_327_08_2017.sav       wschodni               NaN  5.0
# 351423  CBOS_327_08_2017.sav       wschodni               NaN  5.0
# 352155  CBOS_328_09_2017.sav       wschodni               NaN  5.0
# 352207  CBOS_328_09_2017.sav       wschodni               NaN  5.0
# 352450  CBOS_328_09_2017.sav       północny               NaN  5.0
#
#                                 cs_L  \
# 2       powyżej 500 tys. mieszkańców
# 3       powyżej 500 tys. mieszkańców
# 4       powyżej 500 tys. mieszkańców
# 5       powyżej 500 tys. mieszkańców
# 6       powyżej 500 tys. mieszkańców
# ...                              ...
# 351422  powyżej 500 tys. mieszkańców
# 351423  powyżej 500 tys. mieszkańców
# 352155  powyżej 500 tys. mieszkańców
# 352207  powyżej 500 tys. mieszkańców
# 352450  powyżej 500 tys. mieszkańców
#
#                                        teryt_id_VOIV teryt_id_VOIV_500  \
# 2                                            9600000                []
# 3                                            9600000                []
# 4                                            9800000                []
# 5                                            9900000                []
# 6                                            9900000                []
# ...                                              ...               ...
# 351422  ['0600000', '1800000', '2000000', '2600000']                []
# 351423  ['0600000', '1800000', '2000000', '2600000']                []
# 352155  ['0600000', '1800000', '2000000', '2600000']                []
# 352207  ['0600000', '1800000', '2000000', '2600000']                []
# 352450             ['2200000', '2800000', '0400000']                []
#
#        teryt_id_VOIV_100_500  \
# 2                         []
# 3                         []
# 4                         []
# 5                         []
# 6                         []
# ...                      ...
# 351422                    []
# 351423                    []
# 352155                    []
# 352207                    []
# 352450                    []
#
#                                         teryt_id_VOIV_100
# 2                                             ['0461011']
# 3                                             ['0461011']
# 4                                             ['2061011']
# 5                                                      []
# 6                                                      []
# ...                                                   ...
# 351422       ['0663011', '1863011', '2061011', '2661011']
# 351423       ['0663011', '1863011', '2061011', '2661011']
# 352155       ['0663011', '1863011', '2061011', '2661011']
# 352207       ['0663011', '1863011', '2061011', '2661011']
# 352450  ['2261011', '2262011', '2861011', '2862011', '...
#
# [1711 rows x 9 columns]
